# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
# Out:
# Mounted at /content/drive

# %%
# installing textacy 
# !pip install textacy
# Out:
# Collecting textacy
#   Downloading textacy-0.11.0-py3-none-any.whl (200 kB)
#      |████████████████████████████████| 200 kB 6.6 MB/s
# Requirement already satisfied: tqdm>=4.19.6 in /usr/local/lib/python3.7/dist-packages (from textacy) (4.64.0)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (2.23.0)
# Requirement already satisfied: joblib>=0.13.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.1.0)
# Collecting pyphen>=0.10.0
#   Downloading pyphen-0.12.0-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 34.8 MB/s
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.4.1)
# Collecting spacy>=3.0.0
#   Downloading spacy-3.3.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#      |████████████████████████████████| 6.2 MB 20.2 MB/s
# Requirement already satisfied: scikit-learn>=0.19.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.0.2)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (2.6.3)
# Collecting jellyfish>=0.8.0
#   Downloading jellyfish-0.9.0.tar.gz (132 kB)
#      |████████████████████████████████| 132 kB 35.8 MB/s
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (1.21.6)
# Requirement already satisfied: cachetools>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from textacy) (4.2.4)
# Collecting cytoolz>=0.10.1
#   Downloading cytoolz-0.11.2.tar.gz (481 kB)
#      |████████████████████████████████| 481 kB 53.1 MB/s
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from cytoolz>=0.10.1->textacy) (0.11.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->textacy) (2.10)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.19.0->textacy) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (57.4.0)
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Downloading spacy_legacy-3.0.9-py2.py3-none-any.whl (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.7-py3-none-any.whl (17 kB)
# Collecting thinc<8.1.0,>=8.0.14
#   Downloading thinc-8.0.15-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (653 kB)
#      |████████████████████████████████| 653 kB 50.5 MB/s
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (457 kB)
#      |████████████████████████████████| 457 kB 51.2 MB/s
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.2-py3-none-any.whl (7.2 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 46.7 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (21.3)
# Collecting typing-extensions<4.0.0.0,>=3.7.4
#   Downloading typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.5 MB/s
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (0.9.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (3.0.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.11.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (0.4.1)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=3.0.0->textacy) (2.0.6)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp37-cp37m-manylinux2014_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 46.1 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy>=3.0.0->textacy) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy>=3.0.0->textacy) (3.0.8)
# Collecting smart-open<6.0.0,>=5.0.0
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.7 MB/s
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy>=3.0.0->textacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy>=3.0.0->textacy) (2.0.1)
# Building wheels for collected packages: cytoolz, jellyfish
#   Building wheel for cytoolz (setup.py) ... done
#   Created wheel for cytoolz: filename=cytoolz-0.11.2-cp37-cp37m-linux_x86_64.whl size=1230848 sha256=6a0a8bae19daf62498aa133abbace7af57c93140a89d0de0db8443579e60e04c
#   Stored in directory: /root/.cache/pip/wheels/38/70/71/ca13ea3d36ccd0b3d0ec7d7a4ca67522048d695b556bba4f59
#   Building wheel for jellyfish (setup.py) ... done
#   Created wheel for jellyfish: filename=jellyfish-0.9.0-cp37-cp37m-linux_x86_64.whl size=73976 sha256=05faa29908903b46b5890b99ddb0a66a217765eb3468d9a9d08fcfb1d3f1fdab
#   Stored in directory: /root/.cache/pip/wheels/fe/99/4e/646ce766df0d070b0ef04db27aa11543e2767fda3075aec31b
# Successfully built cytoolz jellyfish
# Installing collected packages: typing-extensions, catalogue, typer, srsly, smart-open, pydantic, thinc, spacy-loggers, spacy-legacy, pathy, langcodes, spacy, pyphen, jellyfish, cytoolz, textacy
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.2.0
#     Uninstalling typing-extensions-4.2.0:
#       Successfully uninstalled typing-extensions-4.2.0
#   Attempting uninstall: catalogue
#     Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Attempting uninstall: srsly
#     Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 6.0.0
#     Uninstalling smart-open-6.0.0:
#       Successfully uninstalled smart-open-6.0.0
#   Attempting uninstall: thinc
#     Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Attempting uninstall: spacy
#     Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.8.0 requires tf-estimator-nightly==2.8.0.dev2021122109, which is not installed.
# Successfully installed catalogue-2.0.7 cytoolz-0.11.2 jellyfish-0.9.0 langcodes-3.3.0 pathy-0.6.1 pydantic-1.8.2 pyphen-0.12.0 smart-open-5.2.1 spacy-3.3.0 spacy-legacy-3.0.9 spacy-loggers-1.0.2 srsly-2.4.3 textacy-0.11.0 thinc-8.0.15 typer-0.4.1 typing-extensions-3.10.0.2

# %%
# importing necessary libraries

from sklearn.decomposition import NMF
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from typing import List
import numpy as np
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from textacy.preprocessing.replace import urls, hashtags, numbers, emails, emojis, currency_symbols
from typing import List
import itertools
from textacy.preprocessing.resources import RE_URL
from textacy.preprocessing.resources import RE_SHORT_URL

# %%
## Function to do TF-IDF Vectorization
def vectorizer(df:pd.DataFrame,min_df=0.01,max_df=0.7,ng=(1,1)):
  vectorizer = TfidfVectorizer(ngram_range=ng,\
                               min_df=min_df, max_df=max_df, stop_words="english",binary=True)
  df_1, df_terms = vectorizer.fit_transform(df.description), vectorizer.get_feature_names()
  df_tf_idf = pd.DataFrame(df_1.toarray(), columns=df_terms)
  return df_tf_idf,df_terms

# %%
## Function to get top tokens after topic modelling
## Used from yuchenny repository

def get_top_tf_idf_tokens_for_topic(H: np.array, feature_names: List[str], num_top_tokens: int = 5):
  """
  Uses the H matrix (K components x M original features) to identify for each
  topic the most frequent tokens.
  """
  for topic, vector in enumerate(H):
    print(f"TOPIC {topic}\n")
    total = vector.sum()
    top_scores = vector.argsort()[::-1][:num_top_tokens]
    token_names = list(map(lambda idx: feature_names[idx], top_scores))
    strengths = list(map(lambda idx: vector[idx] / total, top_scores))
    
    for strength, token_name in zip(strengths, token_names):
      print(f"\b{token_name} ({round(strength * 100, 1)}%)\n")
    print(f"=" * 50)

# %%
# Reading the subsetted LA Airbnb dataset, which was done in other ipynb (Data Separation.ipynb)

path = '/content/drive/MyDrive/NLP Project/ABB final/Airbnb_la_text_nlp.csv'
df_la_text = pd.read_csv(path)
df_la_text.head()
# Out:
#    Unnamed: 0         id                                 name  \
# 0           0   986942.0    Attic in Echo Park Hillside House
# 1           1  3249753.0   Art BNB @ Nomad Printmaking Studio
# 2           2  3250095.0  Art BNB @ nomaD Printmaking Studio
# 3           3  3250595.0   Art BNB @ nomAd Printmaking Studio
# 4           4  1941493.0    1915 L.A. River Retreat - Two Bed
#
#                                          description   host_id  \
# 0  Hi Travelers! We have a sweet, spacious attic ...    959023
# 1  Our Punk Shui industrial art space has cool, c...  12772297
# 2  Our Punk Shui industrial art space has cool, c...  12772297
# 3  Our Punk Shui industrial art space has cool, c...  12772297
# 4  Enjoy city & mountain views from the upper uni...  10042199
#
#                                           host_about calendar_last_scraped
# 0  Hi I'm Jonathan. I'm a parent & an artist. I'v...            2015-09-02
# 1  My name is Damon Robinson. I am an LA based ar...            2015-09-02
# 2  My name is Damon Robinson. I am an LA based ar...            2015-09-02
# 3  My name is Damon Robinson. I am an LA based ar...            2015-09-02
# 4  I love history and rivers. My building, which ...            2015-09-02

# %%
# Fetching the month and year only as the data was scraped once per month
df_la_text['my_scraped']= ([x.strftime('%Y-%m') for x in pd.to_datetime(df_la_text.calendar_last_scraped)])

# %%
# Labelling 1 and 0 as during covid and before covid respectively 
## (anything after Jan 2020, as after this date the regulations were being applied on Airbnbs) 
df_la_text['label'] = ([1 if x>'2020-01' else 0 for x in df_la_text['my_scraped']])

# %%
df_la_text.shape
# Out:
# (775528, 9)

# %%
(df_la_text['description'].isna()).sum()
# Out:
# 9875

# %%
# Removing the empty descriptions

df_la_text_refined = df_la_text[df_la_text['description'].notna()]
df_la_text_refined.label.value_counts()
# Out:
# 0    659057
# 1    106596
# Name: label, dtype: int64

# %%
df_la_text_refined.shape
# Out:
# (765653, 9)

# %%
df_la_text_refined.nunique()
# Out:
# Unnamed: 0               765653
# id                        69222
# name                      99384
# description              128217
# host_id                   34308
# host_about                32003
# calendar_last_scraped        82
# my_scraped                   38
# label                         2
# dtype: int64

# %%
# Separating out the pre covid and covid data 

pre_covid=df_la_text_refined[df_la_text_refined.label ==0]
covid = df_la_text_refined[df_la_text_refined.label ==1]

# %%
print(f'Pre covid shape: {pre_covid.shape}')
print(f'After/during covid shape: {covid.shape}')
# Out:
# Pre covid shape: (659057, 9)
# After/during covid shape: (106596, 9)

# %%
# grouping together the relevant terms as key and values, to be used later file pre processing the data 

# Used https://github.com/L-Lewis/Airbnb-neural-network-price-prediction/blob/master/Airbnb-price-prediction.ipynb for amenity collection

reg_clean = {'good':["great","awesome","nice","best","perfect","good","amazing","spectacular","marvelous"],
 'check_in_24h': ['24-hour check-in'],
 'air_conditioning': ["Air conditioning", "Central air conditioning"],
 'high_end_electronics': ['Amazon Echo','Apple TV','Game console','Netflix','Projector and screen','Smart TV','HULU','hulu','netflix','prime video','hdtv','TV','tv'],
  'nature_and_views': ['Beach view','Beachfront','Lake access','Mountain view','Ski-in/Ski-out','Waterfront'],
  'amenities':['Elevator','Gym','gym','Exercise equipment','Bed linens','Coffee maker','Espresso machine','Dishwasher','Dryer','Washer'],
  'luxury':['Hot tub','Jetted tub','hot tub','Sauna','Pool','pool','Balcony','Patio','BBQ grill','Fire pit','Propane barbeque'],
  'child_friendly':['Family/kid friendly','Children','children'],
  'outdoor_space':['Garden','Outdoor','Sun loungers','Terrace'],
  'internet':['Internet','Pocket wifi','Wifi', 'wi fi', 'wi-fi','Wi fi', 'WI FI','WIFI', 'wi  fi'],
  'long_term_stays':['Long term stays allowed'],
  'pets_allowed':['Pets','pet','Cat(s)','Dog(s)'],
  'private_entrance': ['Private entrance'],
  'secure':['Safe','Security system'],
  'self_check_in':['Self check-in'],
  'smoking_allowed':['Smoking allowed'],
  'event_suitable':['Suitable for events'],
  'la': ['LA','los angeles','Los Angeles'],
  'covid':['COVID','COVID 19', 'COVID-19','Covid','covid-19','covid 19','cleaning','cleaned','safety','concerns','clean','disinfect','protection'],
  'location':['Santa Monica','santa monica','beverly hills','Beverly hills','Beverly', 'beverly-hills','marina del ray','universal studio','universal studios','Universal Studio','Universal Studios','beverly  hills','Marina del ray','Marina Del Ray'],
  }

# %% [markdown]
# **Working with listing data during covid phase**

# %%
df1= covid.copy()

# %%
for k in reg_clean:
  df1['description'] = df1['description'].str.replace(r'\b(' + r'|'.join(reg_clean[k]) + r')\b\s*', str(k+' '),regex = True)
  # print(k)

# %%
# Applying textacy

df1["description"] = df1.description.\
  apply(urls).\
  apply(hashtags).\
  apply(numbers).\
  apply(currency_symbols).\
  apply(emojis).\
  apply(emails)
# df.Review_Text

# %%
df1.nunique()
# Out:
# Unnamed: 0               106596
# id                        22171
# name                      24467
# description               25550
# host_id                   12323
# host_about                 9104
# calendar_last_scraped        17
# my_scraped                    6
# label                         1
# dtype: int64

# %%
covid_tf_idf, feature_names = vectorizer(df1)
covid_tf_idf.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# (106596, 1053)

# %%
# Doing a similarity check

## Did this before as well, and whatever the findings were (for covid related terms, we put them in the regex_clean function)

similarity_matrix = pd.DataFrame(cosine_similarity(covid_tf_idf.T.values), 
             columns=feature_names, index=feature_names)

# unstack matrix into table
similarity_table = similarity_matrix.rename_axis(None).rename_axis(None, axis=1).stack().reset_index()

# rename columns
similarity_table.columns = ["word1", "word2", "similarity"]
similarity_table.shape
# Out:
# (1108809, 3)

# %%
similarity_table = similarity_table[similarity_table["similarity"] < 0.99]
similarity_table.shape
# Out:
# (1107756, 3)

# %%
similarity_table.sort_values(by="similarity", ascending=False).drop_duplicates(
    subset="similarity", keep="first").head(10)
# Out:
#            word1        word2  similarity
# 820508       sac          cul    0.952604
# 373341      foam       memory    0.937455
# 247166       del          rey    0.934803
# 883488      solo  adventurers    0.922108
# 362212        fi           wi    0.915662
# 1064837  walking     distance    0.909724
# 691467      pans         pots    0.908186
# 920127     steel    stainless    0.907602
# 665250      oaks      sherman    0.874134
# 597815    marina          rey    0.861106

# %%
# Now the terms like 'cleaning','cleaned','safety','concerns','clean','disinfect','protection' were replaced with covid, they are not here, 
## rest of the similar terms are different in context hence not replacing them

## we did the above thing so as to group together more relevant terms to covid. 
## This was done beacause the number of rows was not that much as compared to the original dataset

temp = similarity_table[similarity_table['word1'].str.contains('covid|pandemic|Covid|COVID|COVID 19')]
temp.sort_values(by="similarity", ascending=False).drop_duplicates(
    subset="similarity", keep="first").head(5)
# Out:
#         word1    word2  similarity
# 227942  covid  kitchen    0.295244
# 227840  covid     good    0.290599
# 228221  covid     room    0.290113
# 227857  covid   guests    0.276237
# 228156  covid  private    0.276163

# %%
## Topic Modelling on the most recent descriptions on the basis of listing id in the covid era

recent_desc= df1[df1.groupby(['id'])['calendar_last_scraped'].transform(max) == df1['calendar_last_scraped']]

covid_recent_tf_idf, feature_recent_covid = vectorizer(recent_desc,ng=(2,2))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
nmf = NMF(n_components=15)
W = nmf.fit_transform(covid_recent_tf_idf)
H = nmf.components_
print(f"Original shape of X sports is {covid_recent_tf_idf.shape}")
print(f"Decomposed W sports matrix is {W.shape}")
print(f"Decomposed H sports matrix is {H.shape}")
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# Original shape of X sports is (22171, 518)
# Decomposed W sports matrix is (22171, 15)
# Decomposed H sports matrix is (15, 518)

# %%
print(f"Airbnb during the covid era description topics:\n\n")
get_top_tf_idf_tokens_for_topic(H, covid_recent_tf_idf.columns.tolist(), num_top_tokens=12)
# Out:
# Airbnb during the covid era description topics:
#
#
# TOPIC 0
#
# walking distance (12.3%)
#
# coffee shops (4.0%)
#
# restaurants bars (3.7%)
#
# shops restaurants (3.2%)
#
# good restaurants (2.4%)
#
# grocery stores (2.3%)
#
# los feliz (1.7%)
#
# distance restaurants (1.6%)
#
# restaurants coffee (1.6%)
#
# bars restaurants (1.5%)
#
# griffith park (1.4%)
#
# distance good (1.4%)
#
# ==================================================
# TOPIC 1
#
# solo adventurers (9.9%)
#
# business travelers (9.2%)
#
# place good (9.1%)
#
# adventurers business (8.9%)
#
# couples solo (8.6%)
#
# good couples (8.5%)
#
# ll love (7.3%)
#
# love place (6.9%)
#
# place close (6.6%)
#
# travelers families (3.8%)
#
# families kids (3.5%)
#
# high ceilings (0.8%)
#
# ==================================================
# TOPIC 2
#
# _number_ bedroom (13.7%)
#
# bedroom _number_ (11.9%)
#
# _number_ bath (8.0%)
#
# _number_ bathroom (6.6%)
#
# bed _number_ (2.4%)
#
# _number_ bed (2.2%)
#
# bathroom apartment (2.0%)
#
# bedroom apartment (1.9%)
#
# spacious _number_ (1.8%)
#
# bath apartment (1.4%)
#
# _number_ _number_ (1.3%)
#
# beautiful _number_ (1.1%)
#
# ==================================================
# TOPIC 3
#
# hidden airbnb (20.3%)
#
# phone number (18.8%)
#
# number hidden (18.6%)
#
# website hidden (4.5%)
#
# korea town (1.5%)
#
# house rules (1.3%)
#
# home located (1.3%)
#
# room available (1.2%)
#
# sunset blvd (1.0%)
#
# _number_ mins (0.9%)
#
# restaurants walking (0.7%)
#
# major freeways (0.7%)
#
# ==================================================
# TOPIC 4
#
# size bed (15.0%)
#
# queen size (13.0%)
#
# king size (4.8%)
#
# bedroom queen (3.1%)
#
# sofa bed (2.0%)
#
# bed _number_ (1.6%)
#
# comfortable queen (1.6%)
#
# master bedroom (1.5%)
#
# bed bedroom (1.4%)
#
# size beds (1.4%)
#
# bathroom shower (1.4%)
#
# _number_ queen (1.4%)
#
# ==================================================
# TOPIC 5
#
# walk fame (10.4%)
#
# hollywood walk (7.8%)
#
# heart hollywood (6.0%)
#
# runyon canyon (4.5%)
#
# hollywood sign (3.9%)
#
# hollywood bowl (3.1%)
#
# hollywood hills (3.1%)
#
# hollywood blvd (3.0%)
#
# chinese theater (2.9%)
#
# hollywood highland (2.8%)
#
# chinese theatre (2.1%)
#
# _number_ nights (1.6%)
#
# ==================================================
# TOPIC 6
#
# living room (12.7%)
#
# dining room (5.6%)
#
# room kitchen (4.9%)
#
# kitchen living (3.8%)
#
# room dining (3.6%)
#
# kitchen dining (2.4%)
#
# dining area (2.3%)
#
# master bedroom (2.0%)
#
# bedroom bathroom (1.8%)
#
# private bedroom (1.5%)
#
# room living (1.4%)
#
# room _number_ (1.4%)
#
# ==================================================
# TOPIC 7
#
# _number_ minutes (7.5%)
#
# _number_ _number_ (4.9%)
#
# venice beach (4.8%)
#
# minutes away (3.0%)
#
# beach _number_ (2.7%)
#
# del rey (2.4%)
#
# marina del (2.3%)
#
# abbot kinney (2.1%)
#
# _number_ miles (1.9%)
#
# location _number_ (1.8%)
#
# minutes location (1.5%)
#
# _number_ blocks (1.4%)
#
# ==================================================
# TOPIC 8
#
# downtown la (12.7%)
#
# staples center (4.8%)
#
# la live (3.4%)
#
# convention center (3.2%)
#
# heart downtown (2.7%)
#
# la _number_ (2.5%)
#
# center la (2.5%)
#
# dodger stadium (1.7%)
#
# located heart (1.5%)
#
# little tokyo (1.3%)
#
# close downtown (1.3%)
#
# la hollywood (1.3%)
#
# ==================================================
# TOPIC 9
#
# fully equipped (2.3%)
#
# brand new (2.3%)
#
# washer dryer (2.2%)
#
# flat screen (2.1%)
#
# screen high_end_electronics (1.8%)
#
# high speed (1.8%)
#
# stainless steel (1.8%)
#
# equipped kitchen (1.8%)
#
# steel appliances (1.6%)
#
# hardwood floors (1.5%)
#
# fully furnished (1.5%)
#
# coffee maker (1.4%)
#
# ==================================================
# TOPIC 10
#
# location hills (12.9%)
#
# west hollywood (7.9%)
#
# hollywood location (4.6%)
#
# centrally located (3.3%)
#
# century city (2.5%)
#
# rodeo drive (2.1%)
#
# hills _number_ (2.1%)
#
# hills hollywood (2.0%)
#
# location center (2.0%)
#
# culver city (1.7%)
#
# la location (1.5%)
#
# location location (1.5%)
#
# ==================================================
# TOPIC 11
#
# _number_ minute (16.6%)
#
# minute walk (13.4%)
#
# minute drive (8.2%)
#
# restaurants bars (1.2%)
#
# echo park (1.2%)
#
# _number_ sq (1.2%)
#
# just _number_ (1.1%)
#
# silver lake (1.1%)
#
# drive location (1.1%)
#
# sq ft (1.0%)
#
# highland park (1.0%)
#
# good restaurants (1.0%)
#
# ==================================================
# TOPIC 12
#
# _number_ bedrooms (11.2%)
#
# bedrooms _number_ (9.9%)
#
# _number_ bathrooms (8.3%)
#
# _number_ baths (2.6%)
#
# house _number_ (2.4%)
#
# _number_ sq (2.0%)
#
# floor plan (1.9%)
#
# sq ft (1.8%)
#
# beds _number_ (1.7%)
#
# home _number_ (1.6%)
#
# features _number_ (1.5%)
#
# open floor (1.4%)
#
# ==================================================
# TOPIC 13
#
# street parking (7.4%)
#
# private room (4.6%)
#
# private bathroom (3.4%)
#
# free street (3.2%)
#
# private entrance (3.0%)
#
# parking available (2.5%)
#
# room private (2.4%)
#
# guest house (1.7%)
#
# private bedroom (1.6%)
#
# main house (1.6%)
#
# plenty street (1.5%)
#
# queen bed (1.4%)
#
# ==================================================
# TOPIC 14
#
# _number_ min (14.8%)
#
# min walk (6.4%)
#
# min drive (5.0%)
#
# min location (4.2%)
#
# just _number_ (4.1%)
#
# center _number_ (2.7%)
#
# min away (2.5%)
#
# shared room (2.5%)
#
# location _number_ (2.4%)
#
# convention center (2.1%)
#
# stores restaurants (2.0%)
#
# _number_ _number_ (1.8%)
#
# ==================================================

# %% [markdown]
# **Subsetting only on covid related descriptions**

# %%
temp = covid[covid['description'].str.contains('covid|pandemic|covid 19|Covid|COVID|COVID 19|safety|ensure|cleaned|cleaning|paramount|concerns|comfort|hulu|netflix')]

# %%
temp.nunique()
# Out:
# Unnamed: 0               30509
# id                        6683
# name                      7439
# description               7793
# host_id                   4041
# host_about                3247
# calendar_last_scraped       17
# my_scraped                   6
# label                        1
# dtype: int64

# %%
temp.shape
# Out:
# (30509, 9)

# %%
for k in reg_clean:
  temp['description'] = temp['description'].str.replace(r'\b(' + r'|'.join(reg_clean[k]) + r')\b\s*', str(k+' '),regex = True)
  # print(k)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Most recent description of respective listing

recent_desc_only_covid= temp[temp.groupby(['id'])['calendar_last_scraped'].transform(max) == temp['calendar_last_scraped']]

# %%
recent_desc_only_covid.shape
# Out:
# (6683, 9)

# %%
recent_desc_only_covid["description"] = recent_desc_only_covid.description.\
  apply(urls).\
  apply(hashtags).\
  apply(numbers).\
  apply(currency_symbols).\
  apply(emojis).\
  apply(emails)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
covid_only_tf_idf, feature_only_covid = vectorizer(recent_desc_only_covid,ng=(1,1))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Tried various n grams from here on

nmf = NMF(n_components=10)
W = nmf.fit_transform(covid_only_tf_idf)
H = nmf.components_
print(f"Original shape of X sports is {covid_only_tf_idf.shape}")
print(f"Decomposed W sports matrix is {W.shape}")
print(f"Decomposed H sports matrix is {H.shape}")

print(f"Airbnb during the covid related description topics:\n\n")
get_top_tf_idf_tokens_for_topic(H, covid_only_tf_idf.columns.tolist(), 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# Original shape of X sports is (6683, 1195)
# Decomposed W sports matrix is (6683, 10)
# Decomposed H sports matrix is (10, 1195)
# Airbnb during the covid related description topics:
#
#
# TOPIC 0
#
# walking (1.0%)
#
# distance (1.0%)
#
# hollywood (1.0%)
#
# close (1.0%)
#
# restaurants (1.0%)
#
# downtown (0.9%)
#
# la (0.9%)
#
# location (0.9%)
#
# away (0.8%)
#
# neighborhood (0.8%)
#
# ==================================================
# TOPIC 1
#
# high_end_electronics (1.2%)
#
# queen (1.2%)
#
# coffee (1.1%)
#
# bed (1.1%)
#
# microwave (1.0%)
#
# size (0.9%)
#
# dryer (0.9%)
#
# towels (0.9%)
#
# internet (0.9%)
#
# equipped (0.9%)
#
# ==================================================
# TOPIC 2
#
# charged (1.8%)
#
# tcl (1.8%)
#
# lost (1.8%)
#
# dolby (1.8%)
#
# checked (1.8%)
#
# laws (1.8%)
#
# load (1.8%)
#
# sqft (1.8%)
#
# allows (1.7%)
#
# 1st (1.7%)
#
# ==================================================
# TOPIC 3
#
# house (1.0%)
#
# home (0.9%)
#
# private (0.7%)
#
# dining (0.7%)
#
# living (0.7%)
#
# large (0.7%)
#
# outdoor (0.7%)
#
# room (0.7%)
#
# beautiful (0.7%)
#
# backyard (0.6%)
#
# ==================================================
# TOPIC 4
#
# review (1.8%)
#
# inquiry (1.8%)
#
# understanding (1.8%)
#
# rules (1.8%)
#
# courtesy (1.8%)
#
# camera (1.8%)
#
# interested (1.8%)
#
# towel (1.8%)
#
# date (1.8%)
#
# follow (1.8%)
#
# ==================================================
# TOPIC 5
#
# switches (1.5%)
#
# thoroughly (1.5%)
#
# knobs (1.5%)
#
# handles (1.5%)
#
# remotes (1.5%)
#
# properties (1.5%)
#
# dear (1.5%)
#
# surfaces (1.5%)
#
# peace (1.4%)
#
# measures (1.4%)
#
# ==================================================
# TOPIC 6
#
# devices (1.7%)
#
# usb (1.6%)
#
# hospitality (1.6%)
#
# complex (1.6%)
#
# pleasure (1.6%)
#
# maximum (1.6%)
#
# taste (1.6%)
#
# charge (1.6%)
#
# enjoyable (1.6%)
#
# apps (1.6%)
#
# ==================================================
# TOPIC 7
#
# team (1.2%)
#
# covid (1.1%)
#
# check (0.9%)
#
# guests (0.9%)
#
# stay (0.9%)
#
# service (0.8%)
#
# soap (0.8%)
#
# time (0.8%)
#
# stand (0.8%)
#
# extra (0.8%)
#
# ==================================================
# TOPIC 8
#
# stainless (1.7%)
#
# steel (1.7%)
#
# appliances (1.6%)
#
# counter (1.3%)
#
# features (1.3%)
#
# tops (1.3%)
#
# quartz (1.2%)
#
# designer (1.2%)
#
# cabinets (1.2%)
#
# gourmet (1.2%)
#
# ==================================================
# TOPIC 9
#
# venice (3.2%)
#
# beach (3.0%)
#
# kinney (2.2%)
#
# abbot (1.9%)
#
# marina (1.3%)
#
# del (1.2%)
#
# rey (1.2%)
#
# boardwalk (1.1%)
#
# ocean (1.1%)
#
# bike (1.1%)
#
# ==================================================

# %%
covid_only_tf_idf_2, feature_only_covid_2 = vectorizer(recent_desc_only_covid,ng=(2,2))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
nmf = NMF(n_components=10)
W = nmf.fit_transform(covid_only_tf_idf_2)
H = nmf.components_
print(f"Original shape of X sports is {covid_only_tf_idf_2.shape}")
print(f"Decomposed W sports matrix is {W.shape}")
print(f"Decomposed H sports matrix is {H.shape}")


print(f"Airbnb description topics for only covid related descriptions:\n\n")
get_top_tf_idf_tokens_for_topic(H, covid_only_tf_idf_2.columns.tolist(), 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# Original shape of X sports is (6683, 683)
# Decomposed W sports matrix is (6683, 10)
# Decomposed H sports matrix is (10, 683)
# Airbnb description topics for only covid related descriptions:
#
#
# TOPIC 0
#
# size bed (2.6%)
#
# living room (2.6%)
#
# queen size (2.6%)
#
# comfortable queen (1.3%)
#
# fully equipped (1.2%)
#
# dining room (1.2%)
#
# private room (1.1%)
#
# queen bed (1.0%)
#
# equipped kitchen (1.0%)
#
# kitchen living (1.0%)
#
# ==================================================
# TOPIC 1
#
# walking distance (2.1%)
#
# _number_ minutes (1.8%)
#
# location hills (1.6%)
#
# _number_ minute (1.3%)
#
# _number_ _number_ (1.3%)
#
# venice beach (1.2%)
#
# centrally located (1.2%)
#
# street parking (1.0%)
#
# minute walk (0.9%)
#
# minutes away (0.9%)
#
# ==================================================
# TOPIC 2
#
# chinese theater (3.7%)
#
# additional guest (3.7%)
#
# beautifully renovated (3.7%)
#
# professionally managed (3.7%)
#
# _cur__number_ fee (3.7%)
#
# guests staying (3.7%)
#
# check _number_ (3.7%)
#
# _cur__number_ _cur__number_ (3.7%)
#
# theater _number_ (3.7%)
#
# min hollywood (3.6%)
#
# ==================================================
# TOPIC 3
#
# walk fame (3.6%)
#
# hollywood walk (3.5%)
#
# house rules (3.3%)
#
# mins drive (3.3%)
#
# rules booking (3.2%)
#
# review house (3.2%)
#
# essentials provided (3.2%)
#
# respect privacy (3.2%)
#
# _number_ mins (3.2%)
#
# home located (3.2%)
#
# ==================================================
# TOPIC 4
#
# business travelers (7.4%)
#
# solo adventurers (6.9%)
#
# adventurers business (6.5%)
#
# place good (6.1%)
#
# couples solo (6.0%)
#
# good couples (5.8%)
#
# ll love (4.0%)
#
# love place (3.7%)
#
# travelers families (3.5%)
#
# families kids (3.1%)
#
# ==================================================
# TOPIC 5
#
# _number_ bedroom (5.9%)
#
# bedroom _number_ (5.3%)
#
# _number_ bath (3.5%)
#
# _number_ bathroom (3.3%)
#
# bed _number_ (1.5%)
#
# bathroom apartment (1.4%)
#
# spacious _number_ (1.3%)
#
# _number_ bed (1.2%)
#
# _number_ queen (1.1%)
#
# living room (1.0%)
#
# ==================================================
# TOPIC 6
#
# stainless steel (3.1%)
#
# steel appliances (3.0%)
#
# _number_ bedrooms (3.0%)
#
# bedrooms _number_ (2.9%)
#
# _number_ bathrooms (2.6%)
#
# flat screen (2.5%)
#
# floor plan (2.5%)
#
# screen high_end_electronics (2.5%)
#
# features _number_ (2.0%)
#
# high_end_electronics living (1.9%)
#
# ==================================================
# TOPIC 7
#
# downtown la (3.7%)
#
# convention center (2.4%)
#
# wi fi (2.2%)
#
# make sure (2.1%)
#
# staples center (2.1%)
#
# _number_ years (2.0%)
#
# located downtown (1.8%)
#
# built _number_ (1.8%)
#
# high speed (1.8%)
#
# apartment complex (1.8%)
#
# ==================================================
# TOPIC 8
#
# covid _number_ (5.3%)
#
# ensure covid (3.5%)
#
# covid measures (3.2%)
#
# peace mind (2.9%)
#
# thoroughly covid (2.9%)
#
# covid surfaces (2.8%)
#
# covid comfort (2.8%)
#
# guest covid (2.8%)
#
# parking _number_ (2.3%)
#
# brand new (2.2%)
#
# ==================================================
# TOPIC 9
#
# hidden airbnb (12.2%)
#
# phone number (10.8%)
#
# number hidden (10.6%)
#
# website hidden (3.0%)
#
# _number_ _number_ (0.9%)
#
# room _number_ (0.9%)
#
# style home (0.8%)
#
# la offer (0.8%)
#
# hollywood sign (0.7%)
#
# sq ft (0.7%)
#
# ==================================================

# %%
# Tried running the follwoing, due top memory limitation it didn't run
# for i in range(2, 5):

#     vectorizer = TfidfVectorizer(ngram_range=(i,i))

#     X = vectorizer.fit_transform(recent_desc_only_covid.description)
#     terms = vectorizer.get_feature_names()
#     tf_idf = pd.DataFrame(X.toarray().transpose(), index=terms)

#     tf_idf = tf_idf.sum(axis=1)
#     score = pd.DataFrame(tf_idf, columns=["score"])
#     score.sort_values(by="score", ascending=False, inplace=True)
#     print("These are the 5 most common n-grams of size %d"%i)
#     print("{}\n".format(score.head(5)))

# %%
covid_only_tf_idf_5, feature_only_covid_5 = vectorizer(recent_desc_only_covid,ng=(1,5))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
nmf = NMF(n_components=10)
W = nmf.fit_transform(covid_only_tf_idf_5)
H = nmf.components_
print(f"Original shape of X sports is {covid_only_tf_idf_5.shape}")
print(f"Decomposed W sports matrix is {W.shape}")
print(f"Decomposed H sports matrix is {H.shape}")

print(f"Airbnb description topics for only covid related descriptions::\n\n")
get_top_tf_idf_tokens_for_topic(H, covid_only_tf_idf_5.columns.tolist(), 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# Original shape of X sports is (6683, 2029)
# Decomposed W sports matrix is (6683, 10)
# Decomposed H sports matrix is (10, 2029)
# Airbnb description topics for only covid related descriptions::
#
#
# TOPIC 0
#
# queen (1.0%)
#
# bed (0.9%)
#
# size (0.9%)
#
# queen size (0.7%)
#
# size bed (0.7%)
#
# bathroom (0.6%)
#
# high_end_electronics (0.6%)
#
# microwave (0.6%)
#
# queen size bed (0.6%)
#
# towels (0.6%)
#
# ==================================================
# TOPIC 1
#
# walking (0.7%)
#
# distance (0.7%)
#
# walking distance (0.6%)
#
# restaurants (0.6%)
#
# location (0.6%)
#
# la (0.6%)
#
# downtown (0.6%)
#
# close (0.6%)
#
# hollywood (0.6%)
#
# minutes (0.5%)
#
# ==================================================
# TOPIC 2
#
# check _number_ _number_ (1.2%)
#
# _cur__number_ fee (1.2%)
#
# tcl (1.2%)
#
# professionally managed (1.2%)
#
# charged (1.2%)
#
# guests staying (1.2%)
#
# beautifully renovated (1.2%)
#
# dolby theater (1.2%)
#
# additional guest (1.2%)
#
# lost (1.2%)
#
# ==================================================
# TOPIC 3
#
# review house (1.2%)
#
# review house rules (1.2%)
#
# house rules booking (1.2%)
#
# rules booking (1.2%)
#
# mins drive (1.2%)
#
# _number_ mins drive (1.2%)
#
# essentials provided (1.2%)
#
# house rules (1.2%)
#
# thank understanding (1.2%)
#
# review (1.2%)
#
# ==================================================
# TOPIC 4
#
# business travelers (2.0%)
#
# adventurers (1.9%)
#
# solo (1.9%)
#
# solo adventurers (1.9%)
#
# travelers (1.9%)
#
# adventurers business (1.8%)
#
# solo adventurers business (1.8%)
#
# couples (1.8%)
#
# adventurers business travelers (1.8%)
#
# solo adventurers business travelers (1.7%)
#
# ==================================================
# TOPIC 5
#
# stainless (1.0%)
#
# stainless steel (1.0%)
#
# steel (1.0%)
#
# steel appliances (0.9%)
#
# stainless steel appliances (0.9%)
#
# appliances (0.9%)
#
# flat screen high_end_electronics (0.8%)
#
# screen high_end_electronics (0.8%)
#
# flat screen (0.8%)
#
# flat (0.8%)
#
# ==================================================
# TOPIC 6
#
# switches (1.1%)
#
# surfaces (1.1%)
#
# thoroughly (1.1%)
#
# ensure covid (1.1%)
#
# measures (1.1%)
#
# sanitize (1.1%)
#
# peace mind (1.1%)
#
# handles (1.1%)
#
# knobs (1.1%)
#
# covid measures (1.1%)
#
# ==================================================
# TOPIC 7
#
# wi fi (1.0%)
#
# fi (1.0%)
#
# wi (1.0%)
#
# speed wi (1.0%)
#
# speed wi fi (1.0%)
#
# high speed wi fi (1.0%)
#
# high speed wi (1.0%)
#
# apartment complex (1.0%)
#
# located downtown la (1.0%)
#
# located downtown (1.0%)
#
# ==================================================
# TOPIC 8
#
# home (0.6%)
#
# house (0.6%)
#
# living (0.5%)
#
# outdoor (0.4%)
#
# good (0.4%)
#
# dining (0.4%)
#
# private (0.4%)
#
# enjoy (0.4%)
#
# open (0.4%)
#
# large (0.4%)
#
# ==================================================
# TOPIC 9
#
# bedroom _number_ (1.3%)
#
# _number_ bedroom _number_ (1.3%)
#
# _number_ bedroom (1.3%)
#
# _number_ bath (0.9%)
#
# bedroom _number_ bath (0.8%)
#
# _number_ bedroom _number_ bath (0.8%)
#
# bedroom (0.8%)
#
# _number_ bathroom (0.8%)
#
# bedroom _number_ bathroom (0.7%)
#
# _number_ bedroom _number_ bathroom (0.7%)
#
# ==================================================
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,

# %% [markdown]
# **Topic Modelling on Pre covid data**

# %%
pre_covid.nunique()
# Out:
# Unnamed: 0               659057
# id                        66188
# name                      93080
# description              119423
# host_id                   33445
# host_about                30617
# calendar_last_scraped        65
# my_scraped                   32
# label                         1
# dtype: int64

# %%
pre_covid.shape
# Out:
# (659057, 9)

# %%
# Most recent description of respective listing

recent_desc_pre_covid= pre_covid[pre_covid.groupby(['id'])['calendar_last_scraped'].transform(max) == pre_covid['calendar_last_scraped']]

# %%
recent_desc_pre_covid.shape
# Out:
# (66188, 9)

# %%
for k in reg_clean:
  recent_desc_pre_covid['description'] = recent_desc_pre_covid['description'].str.replace(r'\b(' + r'|'.join(reg_clean[k]) + r')\b\s*', str(k+' '),regex = True)
  # print(k)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
recent_desc_pre_covid["description"] = recent_desc_pre_covid.description.\
  apply(urls).\
  apply(hashtags).\
  apply(numbers).\
  apply(currency_symbols).\
  apply(emojis).\
  apply(emails)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
pre_covid_tf_idf, feature_pre_covid = vectorizer(recent_desc_pre_covid,ng=(2,2))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Gonna try multiple n grams

nmf = NMF(n_components=10)
W = nmf.fit_transform(pre_covid_tf_idf)
H = nmf.components_
print(f"Original shape of X sports is {pre_covid_tf_idf.shape}")
print(f"Decomposed W sports matrix is {W.shape}")
print(f"Decomposed H sports matrix is {H.shape}")


print(f"Airbnb before the covid era description topics:\n\n")
get_top_tf_idf_tokens_for_topic(H, pre_covid_tf_idf.columns.tolist(), 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# Original shape of X sports is (66188, 505)
# Decomposed W sports matrix is (66188, 10)
# Decomposed H sports matrix is (10, 505)
# Airbnb before the covid era description topics:
#
#
# TOPIC 0
#
# walking distance (10.0%)
#
# restaurants bars (3.1%)
#
# coffee shops (2.7%)
#
# shops restaurants (2.2%)
#
# good restaurants (2.0%)
#
# grocery stores (1.6%)
#
# los feliz (1.6%)
#
# bars restaurants (1.5%)
#
# echo park (1.5%)
#
# west hollywood (1.4%)
#
# ==================================================
# TOPIC 1
#
# solo adventurers (9.4%)
#
# place good (9.3%)
#
# business travelers (8.9%)
#
# good couples (8.6%)
#
# adventurers business (8.6%)
#
# couples solo (8.4%)
#
# ll love (7.9%)
#
# love place (7.7%)
#
# place close (7.6%)
#
# travelers families (4.0%)
#
# ==================================================
# TOPIC 2
#
# living room (9.5%)
#
# room kitchen (3.6%)
#
# kitchen living (3.5%)
#
# dining room (3.5%)
#
# private room (3.1%)
#
# private bathroom (2.5%)
#
# room dining (2.3%)
#
# private bedroom (2.3%)
#
# bedroom bathroom (1.7%)
#
# access kitchen (1.6%)
#
# ==================================================
# TOPIC 3
#
# walk fame (9.1%)
#
# hollywood walk (6.9%)
#
# heart hollywood (5.4%)
#
# hollywood sign (3.8%)
#
# hollywood blvd (3.5%)
#
# runyon canyon (3.1%)
#
# hollywood hills (2.7%)
#
# chinese theater (2.6%)
#
# hollywood bowl (2.6%)
#
# hollywood highland (2.5%)
#
# ==================================================
# TOPIC 4
#
# _number_ bedroom (16.4%)
#
# bedroom _number_ (13.0%)
#
# _number_ bath (7.7%)
#
# _number_ bathroom (7.5%)
#
# bedroom apartment (3.6%)
#
# bathroom apartment (2.4%)
#
# spacious _number_ (2.0%)
#
# bath apartment (1.9%)
#
# beautiful _number_ (1.4%)
#
# bed _number_ (1.3%)
#
# ==================================================
# TOPIC 5
#
# downtown la (12.7%)
#
# staples center (5.4%)
#
# convention center (4.5%)
#
# la live (4.1%)
#
# center la (3.0%)
#
# heart downtown (2.9%)
#
# la _number_ (2.2%)
#
# la convention (2.1%)
#
# located heart (1.6%)
#
# dodger stadium (1.5%)
#
# ==================================================
# TOPIC 6
#
# _number_ minutes (4.5%)
#
# _number_ _number_ (3.4%)
#
# _number_ min (3.0%)
#
# location hills (2.8%)
#
# _number_ miles (2.1%)
#
# hollywood _number_ (1.9%)
#
# minutes away (1.8%)
#
# location _number_ (1.7%)
#
# lax _number_ (1.2%)
#
# downtown _number_ (1.2%)
#
# ==================================================
# TOPIC 7
#
# size bed (14.8%)
#
# queen size (13.1%)
#
# king size (4.3%)
#
# bedroom queen (2.9%)
#
# room queen (1.6%)
#
# comfortable queen (1.6%)
#
# private bathroom (1.5%)
#
# sofa bed (1.4%)
#
# bathroom shower (1.1%)
#
# private entrance (1.1%)
#
# ==================================================
# TOPIC 8
#
# brand new (2.1%)
#
# fully equipped (1.9%)
#
# washer dryer (1.8%)
#
# _number_ bedrooms (1.6%)
#
# equipped kitchen (1.5%)
#
# bedrooms _number_ (1.4%)
#
# queen bed (1.4%)
#
# hardwood floors (1.3%)
#
# flat screen (1.3%)
#
# high speed (1.3%)
#
# ==================================================
# TOPIC 9
#
# venice beach (8.4%)
#
# _number_ minute (7.0%)
#
# minute walk (5.4%)
#
# abbot kinney (5.4%)
#
# del rey (4.2%)
#
# marina del (4.0%)
#
# minute drive (3.2%)
#
# _number_ blocks (2.6%)
#
# beach _number_ (2.5%)
#
# walk beach (1.7%)
#
# ==================================================

# %%
pre_covid_tf_idf_5, feature_pre_covid_5 = vectorizer(recent_desc_pre_covid,ng=(1,5))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
nmf = NMF(n_components=10)
W = nmf.fit_transform(pre_covid_tf_idf_5)
H = nmf.components_
print(f"Original shape of X sports is {pre_covid_tf_idf_5.shape}")
print(f"Decomposed W sports matrix is {W.shape}")
print(f"Decomposed H sports matrix is {H.shape}")


print(f"Airbnb before the covid era description topics:\n\n")
get_top_tf_idf_tokens_for_topic(H, pre_covid_tf_idf_5.columns.tolist(), 10)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,
# Original shape of X sports is (66188, 1588)
# Decomposed W sports matrix is (66188, 10)
# Decomposed H sports matrix is (10, 1588)
# Airbnb before the covid era description topics:
#
#
# TOPIC 0
#
# home (0.8%)
#
# open (0.7%)
#
# bedrooms (0.7%)
#
# dining (0.7%)
#
# large (0.7%)
#
# house (0.6%)
#
# living (0.6%)
#
# outdoor (0.6%)
#
# views (0.6%)
#
# beautiful (0.6%)
#
# ==================================================
# TOPIC 1
#
# solo adventurers (2.7%)
#
# adventurers (2.7%)
#
# solo (2.6%)
#
# place good (2.6%)
#
# business travelers (2.5%)
#
# adventurers business (2.5%)
#
# solo adventurers business (2.5%)
#
# adventurers business travelers (2.5%)
#
# good couples (2.5%)
#
# solo adventurers business travelers (2.5%)
#
# ==================================================
# TOPIC 2
#
# queen (1.2%)
#
# high_end_electronics (1.1%)
#
# bed (1.1%)
#
# size (1.1%)
#
# size bed (0.8%)
#
# queen size (0.8%)
#
# internet (0.8%)
#
# microwave (0.7%)
#
# fully (0.7%)
#
# dryer (0.7%)
#
# ==================================================
# TOPIC 3
#
# walking distance (2.3%)
#
# distance (2.3%)
#
# walking (2.3%)
#
# restaurants (1.8%)
#
# shops (1.4%)
#
# bars (1.4%)
#
# restaurants bars (0.8%)
#
# park (0.8%)
#
# stores (0.8%)
#
# grocery (0.8%)
#
# ==================================================
# TOPIC 4
#
# room (0.9%)
#
# shared (0.8%)
#
# bathroom (0.8%)
#
# private (0.7%)
#
# house (0.6%)
#
# use (0.6%)
#
# kitchen (0.6%)
#
# available (0.6%)
#
# access (0.6%)
#
# private room (0.5%)
#
# ==================================================
# TOPIC 5
#
# venice (2.9%)
#
# beach (2.9%)
#
# venice beach (2.2%)
#
# kinney (1.8%)
#
# abbot (1.5%)
#
# abbot kinney (1.5%)
#
# marina (1.4%)
#
# del (1.4%)
#
# rey (1.4%)
#
# del rey (1.4%)
#
# ==================================================
# TOPIC 6
#
# center (1.8%)
#
# downtown (1.6%)
#
# downtown la (1.6%)
#
# la (1.4%)
#
# staples (1.2%)
#
# staples center (1.2%)
#
# luxury (1.1%)
#
# convention (1.1%)
#
# convention center (1.1%)
#
# amenities (1.0%)
#
# ==================================================
# TOPIC 7
#
# _number_ bedroom (4.4%)
#
# bedroom _number_ (4.2%)
#
# _number_ bedroom _number_ (4.0%)
#
# bedroom (2.9%)
#
# _number_ bath (2.6%)
#
# _number_ bathroom (2.5%)
#
# bedroom _number_ bathroom (2.4%)
#
# _number_ bedroom _number_ bathroom (2.4%)
#
# bedroom _number_ bath (2.3%)
#
# _number_ bedroom _number_ bath (2.3%)
#
# ==================================================
# TOPIC 8
#
# fame (2.4%)
#
# walk fame (2.4%)
#
# hollywood (2.3%)
#
# hollywood walk (1.8%)
#
# hollywood walk fame (1.7%)
#
# walk (1.7%)
#
# chinese (1.3%)
#
# heart hollywood (1.2%)
#
# hills (1.0%)
#
# location (1.0%)
#
# ==================================================
# TOPIC 9
#
# hidden (5.7%)
#
# hidden airbnb (5.3%)
#
# phone number (5.2%)
#
# number hidden (5.2%)
#
# phone number hidden (5.2%)
#
# number (5.1%)
#
# airbnb (4.8%)
#
# phone (4.7%)
#
# number hidden airbnb (4.6%)
#
# phone number hidden airbnb (4.6%)
#
# ==================================================
